# %%
import numpy as np
import tensorflow as tf 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset=pd.read_csv (r'D:\Deep-learning-revision-\notebook\Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.1 MB

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
sns.countplot(data=dataset, x='Gender', hue='Exited')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
corr=dataset.corr(numeric_only=True)
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True,cmap='coolwarm')
plt.show()

# %%
corr['Exited'].sort_values(ascending=False)
# Out:
# Exited             1.000000
# Age                0.285323
# Balance            0.118533
# EstimatedSalary    0.012097
# CustomerId        -0.006248
# HasCrCard         -0.007138
# Tenure            -0.014001
# RowNumber         -0.016571
# CreditScore       -0.027094
# NumOfProducts     -0.047820
# IsActiveMember    -0.156128
# Name: Exited, dtype: float64

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X=dataset.iloc[:,3:13]
y=dataset.iloc[:,13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X=pd.get_dummies(X,columns=['Geography','Gender'],drop_first=True)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0               1        101348.88              False            False
# 1               1        112542.58              False             True
# 2               0        113931.57              False            False
# 3               0         93826.63              False            False
# 4               1         79084.10              False             True
#
#    Gender_Male
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split (X,y,test_size=0.2,random_state=0,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform (X_test)

# %%
#ann
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU,LeakyReLU
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %%
#input layer
classifier.add (Dense(units=11,activation='relu'))

# %%
classifier.add(Dropout(0.2))#Randomly deactivate 20% of neurons during training.

# %%
#first hidden layer 
classifier.add (Dense(units=7,activation='relu'))

# %%
classifier.add(Dropout(0.2))#Randomly deactivate 20% of neurons during training.

# %%
#second hidden layer 
classifier.add (Dense(units=6,activation='relu'))

# %%
classifier.add(Dropout(0.2))#Randomly deactivate 20% of neurons during training.

# %%
#adding the output layer 

classifier.add (Dense(1,activation='sigmoid'))

# %%
#early stopping 
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_loss',
    save_best_only=True
)

# %%
import tensorflow
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.01)

# %%
classifier.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history = classifier.fit(
    X_train,
    y_train,
    validation_split=0.33,
    batch_size=10,
    epochs=100,
    callbacks=[early_stopping, checkpoint]
)
# Out:
# Epoch 1/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7934 - loss: 0.4807 - val_accuracy: 0.8171 - val_loss: 0.4028
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8164 - loss: 0.4286 - val_accuracy: 0.8440 - val_loss: 0.3712
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8285 - loss: 0.4025 - val_accuracy: 0.8376 - val_loss: 0.3735
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8349 - loss: 0.3954 - val_accuracy: 0.8501 - val_loss: 0.3629
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8341 - loss: 0.3963 - val_accuracy: 0.8376 - val_loss: 0.3731
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8356 - loss: 0.3924 - val_accuracy: 0.8432 - val_loss: 0.3670
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8421 - loss: 0.3822 - val_accuracy: 0.8531 - val_loss: 0.3590
# Epoch 8/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8367 - loss: 0.3883 - val_accuracy: 0.8519 - val_loss: 0.3590
# Epoch 9/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8377 - loss: 0.3809 - val_accuracy: 0.8497 - val_loss: 0.3632
# Epoch 10/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8393 - loss: 0.3853 - val_accuracy: 0.8565 - val_loss: 0.3665
# Epoch 11/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8434 - loss: 0.3791 - val_accuracy: 0.8402 - val_loss: 0.3695
# Epoch 12/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8459 - loss: 0.3751 - val_accuracy: 0.8523 - val_loss: 0.3701
# Epoch 13/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.3764 - val_accuracy: 0.8550 - val_loss: 0.3651
# Epoch 14/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8427 - loss: 0.3781 - val_accuracy: 0.8535 - val_loss: 0.3632
# Epoch 15/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8378 - loss: 0.3845 - val_accuracy: 0.8535 - val_loss: 0.3487
# Epoch 16/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8393 - loss: 0.3840 - val_accuracy: 0.8561 - val_loss: 0.3581
# Epoch 17/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8461 - loss: 0.3710 - val_accuracy: 0.8554 - val_loss: 0.3555
# Epoch 18/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8464 - loss: 0.3771 - val_accuracy: 0.8561 - val_loss: 0.3510
# Epoch 19/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8440 - loss: 0.3753 - val_accuracy: 0.8554 - val_loss: 0.3529
# Epoch 20/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8429 - loss: 0.3776 - val_accuracy: 0.8523 - val_loss: 0.3549
# Epoch 21/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8401 - loss: 0.3787 - val_accuracy: 0.8474 - val_loss: 0.3586
# Epoch 22/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8431 - loss: 0.3827 - val_accuracy: 0.8516 - val_loss: 0.3545
# Epoch 23/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8464 - loss: 0.3725 - val_accuracy: 0.8527 - val_loss: 0.3528
# Epoch 24/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8393 - loss: 0.3802 - val_accuracy: 0.8542 - val_loss: 0.3539
# Epoch 25/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8377 - loss: 0.3738 - val_accuracy: 0.8538 - val_loss: 0.3656

# %%
model_history.history
# Out:
# {'accuracy': [0.7934316396713257,
#   0.8163836598396301,
#   0.8285127878189087,
#   0.8348572254180908,
#   0.8341108560562134,
#   0.835603654384613,
#   0.8421347141265869,
#   0.836723268032074,
#   0.8376562595367432,
#   0.8393356800079346,
#   0.8434409499168396,
#   0.8458667397499084,
#   0.8438141345977783,
#   0.8426945209503174,
#   0.8378428816795349,
#   0.8393356800079346,
#   0.8460533618927002,
#   0.8464265465736389,
#   0.8440007567405701,
#   0.8428811430931091,
#   0.8400821089744568,
#   0.8430677652359009,
#   0.8464265465736389,
#   0.8393356800079346,
#   0.8376562595367432],
#  'loss': [0.4807095527648926,
#   0.4286429286003113,
#   0.402541846036911,
#   0.39537757635116577,
#   0.39634332060813904,
#   0.392435759305954,
#   0.38220083713531494,
#   0.3883107006549835,
#   0.3808620572090149,
#   0.38531267642974854,
#   0.3790806531906128,
#   0.3751198649406433,
#   0.3764263093471527,
#   0.378113716840744,
#   0.3845222592353821,
#   0.3839765191078186,
#   0.3709900975227356,
#   0.3771499991416931,
#   0.37525510787963867,
#   0.3775756359100342,
#   0.3786641061306,
#   0.3826833963394165,
#   0.3725009560585022,
#   0.3801998794078827,
#   0.3737655580043793],
#  'val_accuracy': [0.8171147108078003,
#   0.8439984917640686,
#   0.8375615477561951,
#   0.8500567674636841,
#   0.8375615477561951,
#   0.8432412147521973,
#   0.8530859351158142,
#   0.8519499897956848,
#   0.8496781587600708,
#   0.8564937710762024,
#   0.8402120471000671,
#   0.8523286581039429,
#   0.8549791574478149,
#   0.8534646034240723,
#   0.8534646034240723,
#   0.8561151027679443,
#   0.855357825756073,
#   0.8561151027679443,
#   0.855357825756073,
#   0.8523286581039429,
#   0.847406268119812,
#   0.8515713810920715,
#   0.8527073264122009,
#   0.8542218804359436,
#   0.8538432121276855],
#  'val_loss': [0.4027949273586273,
#   0.3711790144443512,
#   0.3735164701938629,
#   0.3628666400909424,
#   0.37308818101882935,
#   0.3669915497303009,
#   0.3590230643749237,
#   0.35900163650512695,
#   0.3631748855113983,
#   0.36650019884109497,
#   0.3695114552974701,
#   0.37012380361557007,
#   0.36513492465019226,
#   0.36318904161453247,
#   0.3487195670604706,
#   0.3581010103225708,
#   0.3554847836494446,
#   0.35100242495536804,
#   0.3529234528541565,
#   0.35493355989456177,
#   0.3585898280143738,
#   0.3544783294200897,
#   0.3528139293193817,
#   0.3539380431175232,
#   0.3655759394168854]}

# %%
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 11)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │            84 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 815 (3.19 KB)
#  Trainable params: 271 (1.06 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 544 (2.13 KB)

# %%
model_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# ## we are more focused  on validation loss than loss because  validation loss reflects performance on unseen data.
# If we check just loss only and if loss decreases also then also model might fit so it is important to focus on validation loss rather than loss.

# %%
'''
case1:  Training loss decreases and validation loss also decreases then model is learning.
case 2: Training loss decreases, but validation loss starts increasing then model  memorizing training data.
'''
plt.plot(model_history.history['loss'], label='Train Loss')
plt.plot(model_history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
#both decreased in our case which is good

# %%
'''
case 1: Both training and validation accuracy increase then model learning is good .
case 2: Training accuracy keeps increasing but validation accuracy stops improving then model is Overfitting.
'''
plt.plot(model_history.history['accuracy'], label='Train Accuracy')
plt.plot(model_history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
## in our case models is good as both train and val accuracy increases

# %%
y_pred = classifier.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(y_test, y_pred > 0.5)
acc = accuracy_score(y_test, y_pred > 0.5)

print(cm)
print(acc)
# Out:
# [[1526   67]
#  [ 229  178]]
# 0.852
